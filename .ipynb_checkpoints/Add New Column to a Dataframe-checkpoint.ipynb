# %%
import pandas as pd

# %%
# reading csv file
df_exams = pd.read_csv('StudentPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental leave          lunch test preparation  \
# 0  female        group B        bachelor      standard             none
# 1  female        group C    some college      standard        completed
# 2  female        group B          master      standard             none
# 3    male        group A       associate  free/reduced             none
# 4    male        group C    some college      standard             none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# # 1 Adding a new column

# %% [markdown]
# ## 1.1 Adding a new column with a scalar value

# %%
# adding new column to a dataframe
df_exams['language score'] = 70
df_exams
# Out:
#    gender race/ethnicity parental leave          lunch test preparation  \
# 0  female        group B        bachelor      standard             none
# 1  female        group C    some college      standard        completed
# 2  female        group B          master      standard             none
# 3    male        group A       associate  free/reduced             none
# 4    male        group C    some college      standard             none
# 5  female        group B       associate      standard             none
# 6  female        group B    some college      standard             none
#
#    math score  reading score  writing score  language score
# 0          72             72             74              70
# 1          69             90             88              70
# 2          90             95             93              70
# 3          47             57             44              70
# 4          76             78             75              70
# ...

# %% [markdown]
# ## 1.2 Adding a new column with an array

# %% [markdown]
# #### the dataframehas 7 rows, so we need to create an array with 7 elements

# %%
import numpy as np

# %%
# create an array of 7 elements
language_score = np.arange(0,7)

# %%
# length of the array
len(language_score)
# Out:
# 7

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#    gender race/ethnicity parental leave          lunch test preparation  \
# 0  female        group B        bachelor      standard             none
# 1  female        group C    some college      standard        completed
# 2  female        group B          master      standard             none
# 3    male        group A       associate  free/reduced             none
# 4    male        group C    some college      standard             none
# 5  female        group B       associate      standard             none
# 6  female        group B    some college      standard             none
#
#    math score  reading score  writing score  language score
# 0          72             72             74               0
# 1          69             90             88               1
# 2          90             95             93               2
# 3          47             57             44               3
# 4          76             78             75               4
# ...

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1,100, size=7)

# %%
# min vlaue inclusive and high value exclusive
min(int_language_score)
max(int_language_score)
# Out:
# 72

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#    gender race/ethnicity parental leave          lunch test preparation  \
# 0  female        group B        bachelor      standard             none
# 1  female        group C    some college      standard        completed
# 2  female        group B          master      standard             none
# 3    male        group A       associate  free/reduced             none
# 4    male        group C    some college      standard             none
# 5  female        group B       associate      standard             none
# 6  female        group B    some college      standard             none
#
#    math score  reading score  writing score  language score
# 0          72             72             74              26
# 1          69             90             88              72
# 2          90             95             93              64
# 3          47             57             44              45
# 4          76             78             75              19
# ...

# %%
# create random fat numbers between 1 and 100
float_language_score = np.random.uniform(1,100, size=7)

# %%
df_exams['language score'] = int_language_score
df_exams
# Out:
#    gender race/ethnicity parental leave          lunch test preparation  \
# 0  female        group B        bachelor      standard             none
# 1  female        group C    some college      standard        completed
# 2  female        group B          master      standard             none
# 3    male        group A       associate  free/reduced             none
# 4    male        group C    some college      standard             none
# 5  female        group B       associate      standard             none
# 6  female        group B    some college      standard             none
#
#    math score  reading score  writing score  language score
# 0          72             72             74              26
# 1          69             90             88              72
# 2          90             95             93              64
# 3          47             57             44              45
# 4          76             78             75              19
# ...
