# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental leave          lunch test preparation  \
# 0  female        group B        bachelor      standard             none
# 1  female        group C    some college      standard        completed
# 2  female        group B          master      standard             none
# 3    male        group A       associate  free/reduced             none
# 4    male        group C    some college      standard             none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# # 1 Selecting one column

# %% [markdown]
# ## 1.1 Syntax 1

# %%
# selecting a column with [] (perferred way to select a col)
df_exams['gender']
# 1D array (series)
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# 6    female
# Name: gender, dtype: object

# %%
# check out the data type of a column
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series: attributes and methods
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ## 1.2 Syntax 2

# %%
# select a column with .
df_exams.gender
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# 6    female
# Name: gender, dtype: object

# %%
# select a column with . (pitfalls)
# a column that has two words in the name, ie 'math score'
df_exams.math score
# Out:
#   Cell In[10], line 3
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
# select the same column using []
df_exams['math score']
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# 5    71
# 6    88
# Name: math score, dtype: int64
