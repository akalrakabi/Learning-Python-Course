# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv')

# %%
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %% [markdown]
# # 1 duplicated()

# %% [markdown]
# ## 1.1 Example 1

# %%
# find duplicates in 1 column/series
df_laptops['laptop_ID'].duplicated()

# or df_laptops.duplicated('laptop_ID')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: laptop_ID, Length: 99, dtype: bool

# %%
# show elements in dataframe with duplicates in column 'laptop_ID'
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros]
# Index: []

# %%
# duplicates in 2 or more columns
df_laptops.duplicated(['Product','TypeName','Inches'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 94    False
# 95    False
# 96     True
# 97     True
# 98    False
# Length: 99, dtype: bool

# %%
duplicated_var = df_laptops.duplicated(['Product','TypeName','Inches'])

# %%
# show all the values duplicated (except for the first - keep='first')
df_laptops[duplicated_var].sort_values(['Product','TypeName'])
# Out:
#     laptop_ID Company          Product   TypeName  Inches  \
# 10         11      HP           250 G6   Notebook    15.6
# 11         12      HP           250 G6   Notebook    15.6
# 38         39      HP           250 G6   Notebook    15.6
# 64         66      HP           250 G6   Notebook    15.6
# 66         68      HP           250 G6   Notebook    15.6
# 87         89      HP           250 G6   Notebook    15.6
# 52         53      HP           255 G6   Notebook    15.6
# 36         37    Acer         Aspire 3   Notebook    15.6
# 54         55    Acer         Aspire 3   Notebook    15.6
# 84         86    Acer         Aspire 3   Notebook    15.6
# 51         52    Acer  Aspire A515-51G   Notebook    15.6
# 16         17    Dell    Inspiron 3567   Notebook    15.6
# 25         26    Dell    Inspiron 3567   Notebook    15.6
# 48         49    Dell    Inspiron 3567   Notebook    15.6
# 96         98    Dell    Inspiron 3567   Notebook    15.6
# 97         99    Dell    Inspiron 3567   Notebook    15.6
# 72         74    Dell    Inspiron 5570   Notebook    15.6
# 77         79    Dell    Inspiron 5570   Notebook    15.6
# 60         61    Dell    Inspiron 5770   Notebook    17.3
# 85         87    Dell    Inspiron 7577     Gaming    15.6
# 93         95    Dell    Inspiron 7577     Gaming    15.6
# 80         82    Dell    Latitude 5590  Ultrabook    15.6
# 81         83   Apple      MacBook 12"  Ultrabook    12.0
# 34         35   Apple      MacBook Air  Ultrabook    13.3
# 4           5   Apple      MacBook Pro  Ultrabook    13.3
# 6           7   Apple      MacBook Pro  Ultrabook    15.4
# 12         13   Apple      MacBook Pro  Ultrabook    15.4
# 15         16   Apple      MacBook Pro  Ultrabook    13.3
# 17         18   Apple      MacBook Pro  Ultrabook    15.4
# 45         46   Apple      MacBook Pro  Ultrabook    13.3
# 7           8   Apple      Macbook Air  Ultrabook    13.3
# 79         81      HP      ProBook 470   Notebook    17.3
# 33         34    Dell           XPS 13  Ultrabook    13.3
# 89         91    Dell           XPS 13  Ultrabook    13.3
#
#                       ScreenResolution                          Cpu   Ram  \
# 10                            1366x768   Intel Core i5 7200U 2.5GHz   4GB
# 11                   Full HD 1920x1080     Intel Core i3 6006U 2GHz   4GB
# 38                            1366x768   Intel Core i5 7200U 2.5GHz   4GB
# 64                   Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 66                            1366x768     Intel Core i3 6006U 2GHz   4GB
# 87                   Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 52                   Full HD 1920x1080    AMD A6-Series 9220 2.5GHz   4GB
# 36                            1366x768   Intel Core i3 7130U 2.7GHz   4GB
# 54                            1366x768   Intel Core i3 7100U 2.4GHz   4GB
# 84                            1366x768      AMD A9-Series 9420 3GHz   4GB
# 51         IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz   8GB
# 16                   Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 25                            1366x768     Intel Core i3 6006U 2GHz   4GB
# 48                   Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   4GB
# 96                   Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 97                   Full HD 1920x1080     Intel Core i3 6006U 2GHz   4GB
# 72                   Full HD 1920x1080   Intel Core i7 8550U 1.8GHz   8GB
# 77                   Full HD 1920x1080   Intel Core i7 8550U 1.8GHz   8GB
# 60                   Full HD 1920x1080   Intel Core i7 8550U 1.8GHz  16GB
# 85         IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 93                   Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz   8GB
# 80         IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz   8GB
# 81  IPS Panel Retina Display 2304x1440         Intel Core i5 1.3GHz   8GB
# 34                            1440x900         Intel Core i5 1.6GHz   8GB
# 4   IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz   8GB
# 6   IPS Panel Retina Display 2880x1800         Intel Core i7 2.2GHz  16GB
# 12  IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 15  IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 17  IPS Panel Retina Display 2880x1800         Intel Core i7 2.9GHz  16GB
# 45  IPS Panel Retina Display 2560x1600         Intel Core i5 2.0GHz   8GB
# 7                             1440x900         Intel Core i5 1.8GHz   8GB
# 79                   Full HD 1920x1080   Intel Core i5 8250U 1.6GHz   8GB
# 33    Touchscreen / Quad HD+ 3200x1800   Intel Core i7 8550U 1.8GHz  16GB
# 89         IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz   8GB
#
#                   Memory                           Gpu       OpSys  Weight  \
# 10             500GB HDD         Intel HD Graphics 620       No OS  1.86kg
# 11             500GB HDD         Intel HD Graphics 520       No OS  1.86kg
# 38               1TB HDD         Intel HD Graphics 620  Windows 10  1.86kg
# 64             256GB SSD         Intel HD Graphics 620  Windows 10  1.86kg
# 66             500GB HDD                AMD Radeon 520  Windows 10  1.86kg
# 87             256GB SSD         Intel HD Graphics 620  Windows 10  1.96kg
# 52             256GB SSD        AMD Radeon R4 Graphics  Windows 10  1.86kg
# 36               1TB HDD         Intel HD Graphics 620       Linux   2.1kg
# 54               1TB HDD         Intel HD Graphics 620  Windows 10   2.4kg
# 84               1TB HDD                 AMD Radeon R5  Windows 10   2.1kg
# 51             256GB SSD          Nvidia GeForce MX150  Windows 10   2.2kg
# 16             256GB SSD            AMD Radeon R5 M430  Windows 10   2.2kg
# 25               1TB HDD         Intel HD Graphics 520  Windows 10   2.3kg
# 48             256GB SSD            AMD Radeon R5 M430  Windows 10   2.3kg
# 96               1TB HDD            AMD Radeon R5 M430       Linux   2.2kg
# 97             256GB SSD            AMD Radeon R5 M430       Linux   2.2kg
# 72             256GB SSD                AMD Radeon 530  Windows 10   2.2kg
# 77  128GB SSD +  1TB HDD        Intel UHD Graphics 620  Windows 10  2.02kg
# 60  256GB SSD +  2TB HDD                AMD Radeon 530  Windows 10   2.8kg
# 85  128GB SSD +  1TB HDD    Nvidia GeForce GTX 1050 Ti  Windows 10  2.65kg
# 93             256GB SSD       Nvidia GeForce GTX 1060  Windows 10  2.65kg
# 80             256GB SSD        Intel UHD Graphics 620  Windows 10  1.88kg
# 81             512GB SSD         Intel HD Graphics 615       macOS  0.92kg
# 34   256GB Flash Storage        Intel HD Graphics 6000    Mac OS X  1.35kg
# 4              256GB SSD  Intel Iris Plus Graphics 650       macOS  1.37kg
# 6    256GB Flash Storage       Intel Iris Pro Graphics    Mac OS X  2.04kg
# 12             256GB SSD            AMD Radeon Pro 555       macOS  1.83kg
# 15             256GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 17             512GB SSD            AMD Radeon Pro 560       macOS  1.83kg
# 45             256GB SSD       Intel Iris Graphics 540       macOS  1.37kg
# 7    256GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 79  128GB SSD +  1TB HDD          Nvidia GeForce 930MX  Windows 10   2.5kg
# 33             512GB SSD        Intel UHD Graphics 620  Windows 10   1.2kg
# 89             256GB SSD        Intel UHD Graphics 620  Windows 10  1.21kg
#
#     Price_euros
# 10       393.90
# 11       344.99
# 38       488.69
# 64       690.00
# 66       438.69
# 87       598.99
# 52       398.49
# 36       367.00
# 54       384.00
# 84       395.00
# 51       841.00
# 16       745.00
# 25       418.64
# 48       639.00
# 96       599.90
# 97       485.00
# 72       870.00
# 77       855.00
# 60      1299.00
# 85      1349.00
# 93      1195.00
# 80      1096.16
# 81      1510.00
# 34       998.00
# 4       1803.60
# 6       2139.97
# 12      2439.97
# 15      1518.55
# 17      2858.00
# 45      1419.00
# 7       1158.70
# 79       977.00
# 33      1869.00
# 89      1649.00

# %% [markdown]
# ## 1.2 Example 2

# %% [markdown]
# Task: Find the cheapest and most expensive laptop of each company using the sort_values()
# and duplicated() methods (keep "first", "last", and False)

# %%
# sort dataframe ascending by company and price
# cheapest first and most expensive last
df_laptops = df_laptops.sort_values(['Company','Price_euros'])
df_laptops
# Out:
#     laptop_ID    Company             Product   TypeName  Inches  \
# 36         37       Acer            Aspire 3   Notebook    15.6
# 54         55       Acer            Aspire 3   Notebook    15.6
# 74         76       Acer       Aspire E5-475   Notebook    14.0
# 84         86       Acer            Aspire 3   Notebook    15.6
# 5           6       Acer            Aspire 3   Notebook    15.6
# ..        ...        ...                 ...        ...     ...
# 62         63     Lenovo  IdeaPad 520S-14IKB   Notebook    14.0
# 21         22     Lenovo  Legion Y520-15IKBN     Gaming    15.6
# 73         75        MSI          GL72M 7RDX     Gaming    17.3
# 58         59        MSI          GS73VR 7RG     Gaming    17.3
# 70         72  Microsoft      Surface Laptop  Ultrabook    13.5
#
#                ScreenResolution                          Cpu   Ram  \
# 36                     1366x768   Intel Core i3 7130U 2.7GHz   4GB
# 54                     1366x768   Intel Core i3 7100U 2.4GHz   4GB
# 74                     1366x768     Intel Core i3 6006U 2GHz   8GB
# 84                     1366x768      AMD A9-Series 9420 3GHz   4GB
# 5                      1366x768      AMD A9-Series 9420 3GHz   4GB
# ..                          ...                          ...   ...
# 62  IPS Panel Full HD 1920x1080   Intel Core i3 7130U 2.7GHz   8GB
# 21  IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz   8GB
# 73            Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz   8GB
# 58            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 70        Touchscreen 2256x1504   Intel Core i5 7200U 2.5GHz   4GB
#
#                   Memory                      Gpu         OpSys   Weight  \
# 36               1TB HDD    Intel HD Graphics 620         Linux    2.1kg
# 54               1TB HDD    Intel HD Graphics 620    Windows 10    2.4kg
# 74               1TB HDD    Intel HD Graphics 520    Windows 10    2.1kg
# 84               1TB HDD            AMD Radeon R5    Windows 10    2.1kg
# 5              500GB HDD            AMD Radeon R5    Windows 10    2.1kg
# ..                   ...                      ...           ...      ...
# 62             256GB SSD    Intel HD Graphics 620         No OS    1.7kg
# 21  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050    Windows 10    2.5kg
# 73  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050    Windows 10    2.7kg
# 58  256GB SSD +  2TB HDD  Nvidia GeForce GTX 1070    Windows 10   2.43kg
# 70             128GB SSD    Intel HD Graphics 620  Windows 10 S  1.252kg
#
#     Price_euros
# 36        367.0
# 54        384.0
# 74        389.0
# 84        395.0
# 5         400.0
# ..          ...
# 62        599.0
# 21        999.0
# 73       1095.0
# 58       2449.0
# 70       1089.0
#
# [99 rows x 13 columns]

# %%
# check all value categories in "Company" column
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         24
# HP           20
# Asus         17
# Apple        14
# Acer         11
# Lenovo        9
# MSI           2
# Chuwi         1
# Microsoft     1
# Name: count, dtype: int64

# %%
# duplicated values in "Company" columns (defualt -> keep='first'
duplicated_first = df_laptops.duplicated('Company')

# %%
# show dataframe with duplicated values in "Company" column
df_laptops[duplicated_first]

# keep='first' (cheapest laptop per company)
# show dataframe with non duplicated values in "Company" column
df_laptops[~duplicated_first][['Company','Price_euros']]
# Out:
#       Company  Price_euros
# 36       Acer       367.00
# 1       Apple       898.94
# 20       Asus       191.90
# 30      Chuwi       244.99
# 25       Dell       418.64
# 67         HP       229.00
# 35     Lenovo       249.00
# 73        MSI      1095.00
# 70  Microsoft      1089.00

# %%
# check all value categories
df_laptops[~duplicated_first].value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# HP           1
# Lenovo       1
# MSI          1
# Microsoft    1
# Name: count, dtype: int64

# %%
# keep='last'
duplicated_last = df_laptops.duplicated('Company', keep='last')

#keep=False
duplicated_False = df_laptops.duplicated('Company', keep=False)

# %%
# keep='last' (most expensive laptop per company)
# show dataframe with non duplicated values in "company" column
df_laptops[~duplicated_last][['Company','Price_euros']]
# Out:
#       Company  Price_euros
# 95       Acer       847.00
# 17      Apple      2858.00
# 65       Asus      1983.00
# 30      Chuwi       244.99
# 33       Dell      1869.00
# 92         HP      1197.00
# 21     Lenovo       999.00
# 58        MSI      2449.00
# 70  Microsoft      1089.00

# %%
# keep=false
# show dataframe with non duplicated values in "company" column
df_laptops[~duplicated_False]
# Out:
#     laptop_ID    Company         Product   TypeName  Inches  \
# 30         31      Chuwi   LapBook 15.6"   Notebook    15.6
# 70         72  Microsoft  Surface Laptop  Ultrabook    13.5
#
#          ScreenResolution                          Cpu  Ram  \
# 30      Full HD 1920x1080  Intel Atom x5-Z8300 1.44GHz  4GB
# 70  Touchscreen 2256x1504   Intel Core i5 7200U 2.5GHz  4GB
#
#                 Memory                    Gpu         OpSys   Weight  \
# 30  64GB Flash Storage      Intel HD Graphics    Windows 10   1.89kg
# 70           128GB SSD  Intel HD Graphics 620  Windows 10 S  1.252kg
#
#     Price_euros
# 30       244.99
# 70      1089.00

# %%
# all elements in company column are repeated at least once
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         24
# HP           20
# Asus         17
# Apple        14
# Acer         11
# Lenovo        9
# MSI           2
# Chuwi         1
# Microsoft     1
# Name: count, dtype: int64
